# %%
path = "/Users/leoschild/Desktop/LEO/RSDS.nosync/Vorb_Datensatz/"

# Frauen:
f_100307 = path+"F/100307/rfMRI_REST1_LR_hp2000_clean.nii"
f_105014 = path+"F/105014/rfMRI_REST1_LR_hp2000_clean.nii"
f_117122 = path+"F/117122/rfMRI_REST1_LR_hp2000_clean.nii"
f_118528 = path+"F/118528/rfMRI_REST1_LR_hp2000_clean.nii"
f_120111 = path+"F/120111/rfMRI_REST1_LR_hp2000_clean.nii"
f_126325 = path+"F/126325/rfMRI_REST1_LR_hp2000_clean.nii"
f_128127 = path+"F/128127/rfMRI_REST1_LR_hp2000_clean.nii"
f_131217 = path+"F/131217/rfMRI_REST1_LR_hp2000_clean.nii"
f_131722 = path+"F/131722/rfMRI_REST1_LR_hp2000_clean.nii"
f_133019 = path+"F/133019/rfMRI_REST1_LR_hp2000_clean.nii"
f_135932 = path+"F/135932/rfMRI_REST1_LR_hp2000_clean.nii"
f_151223 = path+"F/151223/rfMRI_REST1_LR_hp2000_clean.nii"
f_151627 = path+"F/151627/rfMRI_REST1_LR_hp2000_clean.nii"
f_162733 = path+"F/162733/rfMRI_REST1_LR_hp2000_clean.nii"
f_176542 = path+"F/176542/rfMRI_REST1_LR_hp2000_clean.nii"

# Männer:
m_101309 = path+"M/101309/rfMRI_REST1_LR_hp2000_clean.nii"
m_103111 = path+"M/103111/rfMRI_REST1_LR_hp2000_clean.nii"
m_116524 = path+"M/116524/rfMRI_REST1_LR_hp2000_clean.nii"
m_118932 = path+"M/118932/rfMRI_REST1_LR_hp2000_clean.nii"
m_122620 = path+"M/122620/rfMRI_REST1_LR_hp2000_clean.nii"
m_123117 = path+"M/123117/rfMRI_REST1_LR_hp2000_clean.nii"
m_129028 = path+"M/129028/rfMRI_REST1_LR_hp2000_clean.nii"
m_130013 = path+"M/130013/rfMRI_REST1_LR_hp2000_clean.nii"
m_133928 = path+"M/133928/rfMRI_REST1_LR_hp2000_clean.nii"
m_149741 = path+"M/149741/rfMRI_REST1_LR_hp2000_clean.nii"
m_151526 = path+"M/151526/rfMRI_REST1_LR_hp2000_clean.nii"
m_159340 = path+"M/159340/rfMRI_REST1_LR_hp2000_clean.nii"
m_163129 = path+"M/163129/rfMRI_REST1_LR_hp2000_clean.nii"
m_198451 = path+"M/198451/rfMRI_REST1_LR_hp2000_clean.nii"
m_201111 = path+"M/201111/rfMRI_REST1_LR_hp2000_clean.nii"

# %%
msdl_path="/Users/leoschild/nilearn_data/msdl_atlas"

# %%
import sys

sys.path.insert(1,"/Users/leoschild/Desktop/LEO/RSDS.nosync/RSDS_PD-1/Harish")

import Feature_Extraction_pipeline

# %%
import pandas as pd
pfad_dict = {'f_100307': f_100307, 'f_105014': f_105014, 'f_117122': f_117122,'f_118528': f_118528, 'f_120111':f_120111, 'f_126325':f_126325, 'f_128127': f_128127,'f_131217': f_131217,'f_131722':f_131722,'f_133019':f_133019,'f_135932':f_135932,'f_151223':f_151223,'f_151627':f_151627,'f_162733':f_162733, 'f_176542':f_176542, 'm_101309': m_101309,'m_103111':m_103111,'m_116524':m_116524, 'm_118932': m_118932, 'm_122620':m_122620, 'm_123117':m_123117, 'm_129028': m_129028, 'm_130013': m_130013, 'm_133928': m_133928, 'm_149741': m_149741, 'm_151526': m_151526, 'm_159340':m_159340, 'm_163129':m_163129, 'm_198451':m_198451, 'm_201111':m_201111}
df = pd.DataFrame(list(pfad_dict.items()),columns=['ID', 'Pfade'])
print(df)
# Out:
#           ID                                              Pfade
# 0   f_100307  /Users/leoschild/Desktop/LEO/RSDS.nosync/Vorb_...
# 1   f_105014  /Users/leoschild/Desktop/LEO/RSDS.nosync/Vorb_...
# 2   f_117122  /Users/leoschild/Desktop/LEO/RSDS.nosync/Vorb_...
# 3   f_118528  /Users/leoschild/Desktop/LEO/RSDS.nosync/Vorb_...
# 4   f_120111  /Users/leoschild/Desktop/LEO/RSDS.nosync/Vorb_...
# 5   f_126325  /Users/leoschild/Desktop/LEO/RSDS.nosync/Vorb_...
# 6   f_128127  /Users/leoschild/Desktop/LEO/RSDS.nosync/Vorb_...
# 7   f_131217  /Users/leoschild/Desktop/LEO/RSDS.nosync/Vorb_...
# 8   f_131722  /Users/leoschild/Desktop/LEO/RSDS.nosync/Vorb_...
# 9   f_133019  /Users/leoschild/Desktop/LEO/RSDS.nosync/Vorb_...
# 10  f_135932  /Users/leoschild/Desktop/LEO/RSDS.nosync/Vorb_...
# 11  f_151223  /Users/leoschild/Desktop/LEO/RSDS.nosync/Vorb_...
# 12  f_151627  /Users/leoschild/Desktop/LEO/RSDS.nosync/Vorb_...
# 13  f_162733  /Users/leoschild/Desktop/LEO/RSDS.nosync/Vorb_...
# ...

# %%
for i in range(2, 743): 
    col_name = f'NeueSpalte_{i}'
    df[col_name] = None 

print(df.shape)
print(df.head)
# Out:
# /var/folders/z9/fw7pcckx2jscn_v8wc8q6ml80000gn/T/ipykernel_21694/1869091760.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[col_name] = None
# /var/folders/z9/fw7pcckx2jscn_v8wc8q6ml80000gn/T/ipykernel_21694/1869091760.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[col_name] = None
# ...

# %%
df.keys()[2:]
# Out:
# Index(['NeueSpalte_2', 'NeueSpalte_3', 'NeueSpalte_4', 'NeueSpalte_5',
#        'NeueSpalte_6', 'NeueSpalte_7', 'NeueSpalte_8', 'NeueSpalte_9',
#        'NeueSpalte_10', 'NeueSpalte_11',
#        ...
#        'NeueSpalte_733', 'NeueSpalte_734', 'NeueSpalte_735', 'NeueSpalte_736',
#        'NeueSpalte_737', 'NeueSpalte_738', 'NeueSpalte_739', 'NeueSpalte_740',
#        'NeueSpalte_741', 'NeueSpalte_742'],
#       dtype='object', length=741)

# %%
for index, row in df.iterrows():
    df.loc[index, df.keys()[2:]] = Feature_Extraction_pipeline.extract_features(row['Pfade'], msdl_path)
# Out:
# The Atlas has 39 ROIs, part of the following networks:
# ['Ant IPS' 'Aud' 'Basal' 'Cereb' 'Cing-Ins' 'D Att' 'DMN' 'Dors PCC'
#  'L V Att' 'Language' 'Motor' 'Occ post' 'R V Att' 'Salience' 'Striate'
#  'Temporal' 'Vis Sec'].
# The Atlas has 39 ROIs, part of the following networks:
# ['Ant IPS' 'Aud' 'Basal' 'Cereb' 'Cing-Ins' 'D Att' 'DMN' 'Dors PCC'
#  'L V Att' 'Language' 'Motor' 'Occ post' 'R V Att' 'Salience' 'Striate'
#  'Temporal' 'Vis Sec'].
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 2
#       1 for index, row in df.iterrows():
# ----> 2     df.loc[index, df.keys()[2:]] = Feature_Extraction_pipeline.extract_features(row['Pfade'], msdl_path)
#
# File ~/Desktop/LEO/RSDS.nosync/RSDS_PD-1/Harish/Feature_Extraction_pipeline.py:63, in extract_features(nifti_image_path, atlas_directory_path)
# ...

# %%
print(df)
# Out:
#           ID                                              Pfade NeueSpalte_2  \
# 0   f_100307  /Users/leoschild/Desktop/LEO/RSDS.nosync/Vorb_...     0.842616
# 1   f_105014  /Users/leoschild/Desktop/LEO/RSDS.nosync/Vorb_...     0.801185
# 2   f_117122  /Users/leoschild/Desktop/LEO/RSDS.nosync/Vorb_...     0.909063
# 3   f_118528  /Users/leoschild/Desktop/LEO/RSDS.nosync/Vorb_...     0.766762
# 4   f_128127  /Users/leoschild/Desktop/LEO/RSDS.nosync/Vorb_...     0.774523
# 5   f_131217  /Users/leoschild/Desktop/LEO/RSDS.nosync/Vorb_...      0.88107
# 6   f_131722  /Users/leoschild/Desktop/LEO/RSDS.nosync/Vorb_...     0.859604
# 7   f_133019  /Users/leoschild/Desktop/LEO/RSDS.nosync/Vorb_...     0.904258
# 8   f_135932  /Users/leoschild/Desktop/LEO/RSDS.nosync/Vorb_...     0.955209
# 9   f_151223  /Users/leoschild/Desktop/LEO/RSDS.nosync/Vorb_...     0.931234
# 10  f_151627  /Users/leoschild/Desktop/LEO/RSDS.nosync/Vorb_...     0.352167
# ...

# %%
import pickle
with open('dataframe.pkl', 'wb') as file:
    pickle.dump(df, file)

# %%
df.to_pickle("/Users/leoschild/Desktop/LEO/RSDS.nosync/RSDS_PD-1/_Projekt/df.pkl")
